# %%
from framework.result_helper import compare_methods_ttest, process_data, paper_tables, compare_methods_ttest, throughput_per_method, plot_gact_lambda, break_plot_gact_lambda, plot_process_level_ACT, plot_process_throughput_from_pivot, plot_avg_ct_over_episodes

# %% [markdown]
# ### Scenario 1

# %%
folder_path ="results/*simple0.csv"
df_1, count_data_1 = process_data(folder_path)
df = paper_tables(df_1)
df
# Out:
# method         DRL_MultiAgent_SingleLike  DRL_SingleAgent  DoubleDQNExact  \
#           l
# mean_gact 0.2                       2.53             2.47         1108.13
#           0.4                       2.60             2.63         1011.18
#           0.6                       2.95             2.93         1026.83
#           0.8                       3.42             3.46          692.82
# CI        0.2                       0.06             0.02           66.28
#           0.4                       0.02             0.03           33.24
#           0.6                       0.03             0.03           22.99
#           0.8                       0.05             0.04           14.64
#
# method         FIFO  MuProMAC  RLRAM  Random   SPT
#           l
# mean_gact 0.2  2.63      2.45   3.00    2.66  2.44
#           0.4  2.75      2.67   3.29    2.93  2.64
#           0.6  3.03      2.96   3.42    3.99  2.92
#           0.8  3.47      3.48   4.23   17.96  3.45
# ...

# %%
df.to_latex()
# Out:
# '\\begin{tabular}{llrrrrrrrr}\n\\toprule\n & method & DRL_MultiAgent_SingleLike & DRL_SingleAgent & DoubleDQNExact & FIFO & MuProMAC & RLRAM & Random & SPT \\\\\n & l &  &  &  &  &  &  &  &  \\\\\n\\midrule\n\\multirow[t]{4}{*}{mean_gact} & 0.200000 & 2.530000 & 2.470000 & 1108.130000 & 2.630000 & 2.450000 & 3.000000 & 2.660000 & 2.440000 \\\\\n & 0.400000 & 2.600000 & 2.630000 & 1011.180000 & 2.750000 & 2.670000 & 3.290000 & 2.930000 & 2.640000 \\\\\n & 0.600000 & 2.950000 & 2.930000 & 1026.830000 & 3.030000 & 2.960000 & 3.420000 & 3.990000 & 2.920000 \\\\\n & 0.800000 & 3.420000 & 3.460000 & 692.820000 & 3.470000 & 3.480000 & 4.230000 & 17.960000 & 3.450000 \\\\\n\\cline{1-10}\n\\multirow[t]{4}{*}{CI} & 0.200000 & 0.060000 & 0.020000 & 66.280000 & 0.030000 & 0.030000 & 0.020000 & 0.030000 & 0.020000 \\\\\n & 0.400000 & 0.020000 & 0.030000 & 33.240000 & 0.020000 & 0.030000 & 0.030000 & 0.060000 & 0.020000 \\\\\n & 0.600000 & 0.030000 & 0.030000 & 22.990000 & 0.030000 & 0.040000 & 0.
# ...

# %%
plot_gact_lambda(df=df, scenario_label="(i)", out = "figures/lambda_scenario_1")

# %%
df = throughput_per_method(df=count_data_1, show_process=False)
df
# Out:
# method          DRL_MultiAgent_SingleLike  DRL_SingleAgent  DoubleDQNExact  \
#            l
# throughput 0.2                     498.18           498.35           29.92
#            0.4                     997.25          1000.28           55.18
#            0.6                    1497.65          1503.50          189.12
#            0.8                    1988.58          2012.18          235.70
# CI         0.2                      10.45             9.37            2.97
#            0.4                      13.17            13.84            3.44
#            0.6                      18.17            18.91           12.09
#            0.8                      23.00            24.73           10.69
#
# method             FIFO  MuProMAC    RLRAM   Random      SPT
#            l
# throughput 0.2   502.35    495.60   502.62   501.05   499.65
#            0.4   994.88    993.78   999.08   993.52   996.40
#            0.6  1500.20   1505.70  1505.78  1497.28  1492.92
# ...

# %%
df.to_latex()
# Out:
# '\\begin{tabular}{llrrrrrrrr}\n\\toprule\n & method & DRL_MultiAgent_SingleLike & DRL_SingleAgent & DoubleDQNExact & FIFO & MuProMAC & RLRAM & Random & SPT \\\\\n & l &  &  &  &  &  &  &  &  \\\\\n\\midrule\n\\multirow[t]{4}{*}{throughput} & 0.200000 & 498.180000 & 498.350000 & 29.920000 & 502.350000 & 495.600000 & 502.620000 & 501.050000 & 499.650000 \\\\\n & 0.400000 & 997.250000 & 1000.280000 & 55.180000 & 994.880000 & 993.780000 & 999.080000 & 993.520000 & 996.400000 \\\\\n & 0.600000 & 1497.650000 & 1503.500000 & 189.120000 & 1500.200000 & 1505.700000 & 1505.780000 & 1497.280000 & 1492.920000 \\\\\n & 0.800000 & 1988.580000 & 2012.180000 & 235.700000 & 1992.850000 & 1998.920000 & 2002.120000 & 1988.080000 & 2001.600000 \\\\\n\\cline{1-10}\n\\multirow[t]{4}{*}{CI} & 0.200000 & 10.450000 & 9.370000 & 2.970000 & 9.920000 & 12.440000 & 10.210000 & 11.620000 & 11.910000 \\\\\n & 0.400000 & 13.170000 & 13.840000 & 3.440000 & 13.760000 & 16.290000 & 16.780000 & 13.650000 & 14.780000 \\
# ...

# %%
res = compare_methods_ttest(
    df = df_1,
    method_a="DRL_MultiAgent_SingleLike",
    method_b="SPT",
    alpha=0.05,
    agg="run",  
    l=0.6,
    alternative="two-sided"
)
print(res['significant'])
# Out:
# False

# %% [markdown]
# ### Scenario 2

# %%
folder_path ="results/*simple1.csv"
df_1, count_data_1 = process_data(folder_path)
df = paper_tables(df_1)
df
# Out:
# method         DRL_MultiAgent_SingleLike  DRL_SingleAgent  DoubleDQNExact  \
#           l
# mean_gact 0.2                       2.70             2.59          714.26
#           0.4                       5.02             2.88          605.76
#           0.6                      17.01             3.48         1032.13
#           0.8                      54.58             5.01         1062.69
# CI        0.2                       0.06             0.03           46.49
#           0.4                       0.19             0.04           78.52
#           0.6                       2.66             0.04           21.31
#           0.8                       9.55             0.17           30.96
#
# method           FIFO  MuProMAC  RLRAM  Random   SPT
#           l
# mean_gact 0.2    3.36      2.58   3.10    2.74  2.54
#           0.4    4.86      2.90   3.48    3.30  2.87
#           0.6   12.36      3.51   4.18    6.53  3.44
#           0.8  125.41      4.84   5.82  203.36  5.20
# ...

# %%
df.to_latex()
# Out:
# '\\begin{tabular}{llrrrrrrrr}\n\\toprule\n & method & DRL_MultiAgent_SingleLike & DRL_SingleAgent & DoubleDQNExact & FIFO & MuProMAC & RLRAM & Random & SPT \\\\\n & l &  &  &  &  &  &  &  &  \\\\\n\\midrule\n\\multirow[t]{4}{*}{mean_gact} & 0.200000 & 2.700000 & 2.590000 & 714.260000 & 3.360000 & 2.580000 & 3.100000 & 2.740000 & 2.540000 \\\\\n & 0.400000 & 5.020000 & 2.880000 & 605.760000 & 4.860000 & 2.900000 & 3.480000 & 3.300000 & 2.870000 \\\\\n & 0.600000 & 17.010000 & 3.480000 & 1032.130000 & 12.360000 & 3.510000 & 4.180000 & 6.530000 & 3.440000 \\\\\n & 0.800000 & 54.580000 & 5.010000 & 1062.690000 & 125.410000 & 4.840000 & 5.820000 & 203.360000 & 5.200000 \\\\\n\\cline{1-10}\n\\multirow[t]{4}{*}{CI} & 0.200000 & 0.060000 & 0.030000 & 46.490000 & 0.070000 & 0.040000 & 0.050000 & 0.030000 & 0.020000 \\\\\n & 0.400000 & 0.190000 & 0.040000 & 78.520000 & 0.160000 & 0.040000 & 0.050000 & 0.060000 & 0.030000 \\\\\n & 0.600000 & 2.660000 & 0.040000 & 21.310000 & 1.260000 & 0.050000
# ...

# %%
break_plot_gact_lambda(df=df, scenario_label="(ii)", low_ylim = (0, 8), high_ylim = (15, 60), out = "figures/lambda_scenario_2")
# Out:
# f:\Kiran_KLU\MuProMAC_revision - Copy\framework\result_helper.py:1129: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
df = throughput_per_method(df=count_data_1,show_process=False)
df
# Out:
# method          DRL_MultiAgent_SingleLike  DRL_SingleAgent  DoubleDQNExact  \
#            l
# throughput 0.2                     499.28           503.62           59.60
#            0.4                    1008.72          1002.08          252.48
#            0.6                    1494.08          1494.60          161.85
#            0.8                    1829.22          1993.92          153.93
# CI         0.2                      10.53             8.16            4.52
#            0.4                      15.10            15.69           72.85
#            0.6                      17.59            14.48            6.20
#            0.8                      81.93            24.19           21.96
#
# method             FIFO  MuProMAC    RLRAM   Random      SPT
#            l
# throughput 0.2   497.48    499.00   499.98   499.75   495.32
#            0.4   994.15   1002.52   986.32   993.05   993.65
#            0.6  1483.20   1491.05  1510.92  1495.78  1490.38
# ...

# %%
df.to_latex()
# Out:
# '\\begin{tabular}{llrrrrrrrr}\n\\toprule\n & method & DRL_MultiAgent_SingleLike & DRL_SingleAgent & DoubleDQNExact & FIFO & MuProMAC & RLRAM & Random & SPT \\\\\n & l &  &  &  &  &  &  &  &  \\\\\n\\midrule\n\\multirow[t]{4}{*}{throughput} & 0.200000 & 499.280000 & 503.620000 & 59.600000 & 497.480000 & 499.000000 & 499.980000 & 499.750000 & 495.320000 \\\\\n & 0.400000 & 1008.720000 & 1002.080000 & 252.480000 & 994.150000 & 1002.520000 & 986.320000 & 993.050000 & 993.650000 \\\\\n & 0.600000 & 1494.080000 & 1494.600000 & 161.850000 & 1483.200000 & 1491.050000 & 1510.920000 & 1495.780000 & 1490.380000 \\\\\n & 0.800000 & 1829.220000 & 1993.920000 & 153.930000 & 1814.380000 & 1995.450000 & 2001.480000 & 1685.500000 & 2007.780000 \\\\\n\\cline{1-10}\n\\multirow[t]{4}{*}{CI} & 0.200000 & 10.530000 & 8.160000 & 4.520000 & 8.430000 & 11.710000 & 11.900000 & 10.320000 & 10.130000 \\\\\n & 0.400000 & 15.100000 & 15.690000 & 72.850000 & 11.530000 & 17.820000 & 13.450000 & 16.210000 & 16.05000
# ...

# %%
res = compare_methods_ttest(
    df = df_1,
    method_a="DRL_SingleAgent",
    method_b="SPT",
    alpha=0.05,
    agg="run",
    l=0.6,
    alternative="two-sided"
)
print(res['significant'])
# Out:
# False

# %% [markdown]
# ### Scenario 3

# %%
folder_path ="results/*simple2XY.csv"
df_1, count_data_1 = process_data(folder_path)
df = paper_tables(df_1)
df
# Out:
# method         DRL_MultiAgent_SingleLike  DRL_SingleAgent  DoubleDQNExact  \
#           l
# mean_gact 0.2                       3.94             2.60          496.68
#           0.4                       6.38             3.06          922.45
#           0.6                      27.24             4.11          815.57
#           0.8                      72.81            20.55         1071.66
# CI        0.2                       0.06             0.04           30.25
#           0.4                       0.23             0.05           25.36
#           0.6                       3.71             0.07           33.11
#           0.8                       3.60             3.40           26.06
#
# method           FIFO  MuProMAC  RLRAM  Random   SPT
#           l
# mean_gact 0.2    3.46      2.33   3.15    2.50  2.34
#           0.4    5.59      2.81   3.49    3.17  2.78
#           0.6   29.01      3.61   4.26    7.18  3.66
#           0.8  285.04      6.01   6.98  239.48  6.19
# ...

# %%
df.to_latex()
# Out:
# '\\begin{tabular}{llrrrrrrrr}\n\\toprule\n & method & DRL_MultiAgent_SingleLike & DRL_SingleAgent & DoubleDQNExact & FIFO & MuProMAC & RLRAM & Random & SPT \\\\\n & l &  &  &  &  &  &  &  &  \\\\\n\\midrule\n\\multirow[t]{4}{*}{mean_gact} & 0.200000 & 3.940000 & 2.600000 & 496.680000 & 3.460000 & 2.330000 & 3.150000 & 2.500000 & 2.340000 \\\\\n & 0.400000 & 6.380000 & 3.060000 & 922.450000 & 5.590000 & 2.810000 & 3.490000 & 3.170000 & 2.780000 \\\\\n & 0.600000 & 27.240000 & 4.110000 & 815.570000 & 29.010000 & 3.610000 & 4.260000 & 7.180000 & 3.660000 \\\\\n & 0.800000 & 72.810000 & 20.550000 & 1071.660000 & 285.040000 & 6.010000 & 6.980000 & 239.480000 & 6.190000 \\\\\n\\cline{1-10}\n\\multirow[t]{4}{*}{CI} & 0.200000 & 0.060000 & 0.040000 & 30.250000 & 0.080000 & 0.030000 & 0.040000 & 0.030000 & 0.030000 \\\\\n & 0.400000 & 0.230000 & 0.050000 & 25.360000 & 0.270000 & 0.020000 & 0.040000 & 0.060000 & 0.040000 \\\\\n & 0.600000 & 3.710000 & 0.070000 & 33.110000 & 3.630000 & 0.060000
# ...

# %%
break_plot_gact_lambda(df=df, scenario_label="(iii)", low_ylim = (0, 8), high_ylim = (15.2, 75), out = "figures/lambda_scenario_3")
# Out:
# f:\Kiran_KLU\MuProMAC_revision - Copy\framework\result_helper.py:1129: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
plot_process_level_ACT(df=df_1, out = "figures/process_level_scenario_3_ACT")
# Out:
# f:\Kiran_KLU\MuProMAC_revision - Copy\framework\result_helper.py:1148: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   means = df.loc["mean_act"].stack(level=[0,1]).reset_index()
# f:\Kiran_KLU\MuProMAC_revision - Copy\framework\result_helper.py:1151: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cis = df.loc["CI"].stack(level=[0,1]).reset_index()

# %%
df_throughput = throughput_per_method(df=count_data_1, show_process=True)

plot_process_throughput_from_pivot(
    df_throughput,  # the pivot from throughput_per_method(..., show_process=True)
    included_methods=("DRL_MultiAgent_SingleLike","DRL_SingleAgent","MuProMAC"),
    process_label_map={"process_a":"P1","process_b":"P2"},
    out="figures/process_level_scenario_3_ATP",
    print_bw=False,
    show_ci=True
)

# %%
df_throughput
# Out:
# method                    DRL_MultiAgent_SingleLike  DRL_SingleAgent  \
#            l   process
# throughput 0.2 process_a                     501.35           504.10
#                process_b                     496.50           497.25
#            0.4 process_a                    1001.90          1000.00
#                process_b                    1002.25          1013.65
#            0.6 process_a                    1458.65          1481.95
#                process_b                    1484.20          1492.50
#            0.8 process_a                    1540.45          1997.25
#                process_b                    1545.00          1926.85
# CI         0.2 process_a                       9.09            11.24
#                process_b                      11.03            12.60
#            0.4 process_a                      18.51            13.05
#                process_b                      15.09            12.66
# ...

# %%
res = compare_methods_ttest(
    df = df_1,
    method_a="DRL_SingleAgent",
    method_b="SPT",
    alpha=0.05,
    agg="run",   # or "case"
    l=0.6,
    alternative="two-sided"
)
print(res['significant'])
# Out:
# True

# %% [markdown]
# ### Scenario 4

# %%
folder_path ="results/*simple2XY_fast_slow.csv"
df_1, count_data_1 = process_data(folder_path)
df = paper_tables(df_1)
df
# Out:
# method         DRL_MultiAgent_SingleLike  DRL_SingleAgent  DoubleDQNExact  \
#           l
# mean_gact 0.2                       6.42             4.18          720.71
#           0.4                      32.27             7.17         1025.15
#           0.6                     105.66            76.55         1098.08
#           0.8                     220.24            85.00          708.46
# CI        0.2                       0.18             0.06           31.23
#           0.4                       5.05             0.24           37.96
#           0.6                       3.37             9.88           33.15
#           0.8                      15.08             5.60           19.68
#
# method           FIFO  MuProMAC  RLRAM  Random    SPT
#           l
# mean_gact 0.2    4.76      2.72   3.18    3.09   2.70
#           0.4   12.05      3.51   4.04    4.42   3.54
#           0.6  157.64      5.58   6.81   60.96   5.75
#           0.8  403.05     23.06  25.23  406.02  37.01
# ...

# %%
low_ylim  = (0, 40)       
high_ylim = (70, 235)     
break_plot_gact_lambda(df=df, scenario_label="(iii)", low_ylim = low_ylim, high_ylim = high_ylim, out = "figures/lambda_scenario_4")
# Out:
# f:\Kiran_KLU\MuProMAC_revision - Copy\framework\result_helper.py:1129: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
plot_process_level_ACT(df=df_1, out = "figures/process_level_scenario_4_ACT")
# Out:
# f:\Kiran_KLU\MuProMAC_revision - Copy\framework\result_helper.py:1148: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   means = df.loc["mean_act"].stack(level=[0,1]).reset_index()
# f:\Kiran_KLU\MuProMAC_revision - Copy\framework\result_helper.py:1151: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cis = df.loc["CI"].stack(level=[0,1]).reset_index()

# %%
df_throughput = throughput_per_method(df=count_data_1, show_process=True)

plot_process_throughput_from_pivot(
    df_throughput,  # the pivot from throughput_per_method(..., show_process=True)
    included_methods=("DRL_MultiAgent_SingleLike","DRL_SingleAgent","MuProMAC"),
    process_label_map={"process_a":"P1","process_b":"P2"},
    out="figures/process_level_scenario_3_ATP",
    print_bw=False,
    show_ci=True
)

# %%
df = throughput_per_method(df=count_data_1, show_process=False)
df
# Out:
# method          DRL_MultiAgent_SingleLike  DRL_SingleAgent  DoubleDQNExact  \
#            l
# throughput 0.2                     493.78           492.62           56.30
#            0.4                     962.28           999.38           50.60
#            0.6                    1212.25          1277.60           82.05
#            0.8                    1248.22          1470.42          258.85
# CI         0.2                       9.88            11.83            3.41
#            0.4                      17.32            16.34            4.17
#            0.6                     121.37           103.51            4.78
#            0.8                     141.41           243.76           43.69
#
# method             FIFO  MuProMAC    RLRAM   Random      SPT
#            l
# throughput 0.2   497.52    501.20   493.08   497.22   503.22
#            0.4  1000.85    989.80   996.05  1000.08   997.70
#            0.6  1325.28   1495.78  1495.08  1429.88  1501.97
# ...

# %% [markdown]
# ### Scenario 5

# %%
folder_path ="results/*bpi2020_2processes_massive_share.csv"
df_1, count_data_1 = process_data(folder_path)
paper_tables(df_1)
# Out:
# method         DRL_MultiAgent_SingleLike  DRL_SingleAgent  FIFO  MuProMAC  \
#           l
# mean_gact 0.2                       6.52             6.55  9.53      6.57
# CI        0.2                       0.03             0.04  0.06      0.04
#
# method         RLRAM  Random   SPT
#           l
# mean_gact 0.2   8.78    7.99  6.50
# CI        0.2   0.17    0.04  0.04

# %%
throughput_per_method(df=count_data_1, show_process=False)
# Out:
# method          DRL_MultiAgent_SingleLike  DRL_SingleAgent    FIFO  MuProMAC  \
#            l
# throughput 0.2                     497.92           499.96  497.38    497.04
# CI         0.2                       5.99             5.64    5.79      5.79
#
# method           RLRAM  Random     SPT
#            l
# throughput 0.2  501.44  498.88  491.39
# CI         0.2    6.89    6.37    6.09

# %%
csvs = {
    r"trained_models/DRL_SingleAgent/bpi2020_2processes_massive_share_lambda0.2/training_log.csv": "DRL (SA)",
    r"trained_models/MuProMAC/bpi2020_2processes_massive_share_lambda0.2/training_log.csv": "MuProMAC",
    r"trained_models/DRLMultiAgent/bpi2020_2processes_massive_share_lambda0.2/training_log.csv": "DRL (MA)"
}

plot_avg_ct_over_episodes(
    csv_paths=list(csvs.keys()),
    method_name_overrides=csvs,   
    methods_filter=None,        
    smooth=20,                     
    #out_png="figures/gact_vs_episode.png",                 
    figsize=(6.4, 4.2),
    dpi=400
)
# Out:
# f:\Kiran_KLU\MuProMAC_revision - Copy\framework\result_helper.py:1535: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g.assign(avg_cycle_time_smooth=g["avg_cycle_time"]
