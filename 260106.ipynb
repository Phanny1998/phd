# %%
import pandas as pd
data = pd.read_csv("out/251110/event_logs_processed/FIFO_EXP_l0.28_dedicated_C1_V18_A5_QC97_identical.csv", sep=";")
case_lengths = data.groupby('case_id').size()
print(f"Max events per case: {case_lengths.max()}")
print(f"Mean events per case: {case_lengths.mean():.1f}")
print(case_lengths.value_counts().sort_index())
# Out:
# Max events per case: 8
# Mean events per case: 5.1
# 5    6071
# 6     841
# 7      78
# 8       2
# Name: count, dtype: int64
